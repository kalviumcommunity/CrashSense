# %% [markdown]
# # My First Notebook
# This notebook demonstrates Code and Markdown usage.

# %% [markdown]
# ## Adding Two Numbers
# This code will add two numbers.

# %%
a = 5
b = 10
print(a + b)
# Out:
# 15

# %% [markdown]
# The output shows the sum of two numbers.

# %%
x = 10
print(x)
# Out:
# 10

# %%
while True:
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 while True:
#       2     pass
#
# KeyboardInterrupt:

# %%
2
