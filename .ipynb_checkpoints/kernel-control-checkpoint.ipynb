# %% [markdown]
# # Kernel Management Demo
#
# This notebook demonstrates how to run, interrupt, and restart Jupyter kernels.

# %%
x = 10
y = 5
print("Sum:", x + y)
# Out:
# Sum: 15

# %%
print("Value of x is:", x)
# Out:
# Value of x is: 10

# %%
import time

for i in range(100):
    print(i)
    time.sleep(1)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       3 for i in range(100):
#       4     print(i)
# ----> 5     time.sleep(1)
#
# KeyboardInterrupt:

# %%
print(x)
