# %% [markdown]
# # Markdown Demonstration Notebook
#
# This notebook demonstrates proper usage of Markdown cells in Jupyter Notebook for clear documentation and readability.

# %% [markdown]
# ## Purpose
#
# - Understand how Markdown improves readability
# - Separate explanation from code
# - Demonstrate headings, lists, and formatting

# %%
x = 10
y = 5
print("Sum:", x + y)
# Out:
# Sum: 15

# %% [markdown]
# ### Explanation of Above Code
#
# - We created two variables: `x` and `y`
# - Then we calculated their sum
# - The result is printed using `print()`

# %% [markdown]
# ## Steps Performed
#
# 1. Defined variables
# 2. Performed addition
# 3. Printed output

# %% [markdown]
# ### Example Code Block
#
# ```python
# a = 2
# b = 3
# print(a * b)

# %% [markdown]
# ```python
# print("Notebook is working correctly!")
